# %%
# %matplotlib inline
import requests
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.signal import savgol_filter
import csv
import geopandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-161b21c2d562> in <module>
#       6 from scipy.signal import savgol_filter
#       7 import csv
# ----> 8 import geopandas
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
nypd_complaint_2020 = pd.read_csv('data/nypd_complaint_2020_cleaned.csv')
nypd_complaint_2019 = pd.read_csv('data/nypd_complaint_2019_cleaned.csv')

# %%
nypd_complaint_2019
# Out:
#       Unnamed: 0        date        level susp_age_group       susp_race  \
# 0              0  05/08/2019       FELONY          45-64           BLACK
# 1              1  11/24/2019       FELONY          25-44           BLACK
# 2              2  05/07/2019  MISDEMEANOR          45-64  WHITE HISPANIC
# 3              3  06/17/2019       FELONY        UNKNOWN         UNKNOWN
# 4              4  07/17/2019    VIOLATION          45-64           BLACK
# ...          ...         ...          ...            ...             ...
# 6561        6562  12/13/2019       FELONY          25-44           BLACK
# 6562        6563  12/24/2019  MISDEMEANOR        UNKNOWN           WHITE
# 6563        6564  12/24/2019       FELONY        UNKNOWN         UNKNOWN
# 6564        6565  12/05/2019       FELONY        UNKNOWN         UNKNOWN
# 6565        6566  12/16/2019       FELONY        UNKNOWN         UNKNOWN
#
#      susp_sex vic_age_group        vic_race vic_sex   latitude  longitude
# 0           M           65+           BLACK       M  40.823101 -73.869690
# 1           M         25-44           BLACK       M  40.822570 -73.911307
# 2           M         45-64           BLACK       F  40.849712 -73.830373
# 3      Others         45-64  WHITE HISPANIC       M  40.715414 -73.905945
# 4           F         25-44           BLACK       F  40.666796 -73.896512
# ...       ...           ...             ...     ...        ...        ...
# 6561        M         25-44           WHITE       M  40.795695 -73.938737
# 6562        M         45-64           WHITE       F  40.634049 -74.076606
# 6563   Others       UNKNOWN         UNKNOWN       D  40.776140 -73.910701
# 6564   Others         45-64  WHITE HISPANIC       M  40.862924 -73.893857
# 6565   Others         45-64           WHITE       M  40.676570 -73.845620
#
# [6566 rows x 11 columns]
