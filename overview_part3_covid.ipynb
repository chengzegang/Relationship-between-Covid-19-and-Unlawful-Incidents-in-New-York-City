# %%
# %matplotlib notebook
import requests
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.signal import savgol_filter
import csv
import geopandas as gpd
import shapely.geometry as sgeo

# %%
data20 = pd.read_csv('data/nypd_complaint_2020_geo_cleaned.csv')
data19 = pd.read_csv('data/nypd_complaint_2019_geo_cleaned.csv')

# %%
data20_felony = data20[data20['level'] == 'FELONY']
data19_felony = data19[data19['level'] == 'FELONY']

# %%
print('felony ratio in 2019: ' + str(len(data19_felony) / len(data19)))
print('felony ratio in 2020: ' + str(len(data20_felony) / len(data20)))
# Out:
# felony ratio in 2019: 0.46009747182455074
# felony ratio in 2020: 0.32303489431914456

# %%
data2
# Out:
#         Unnamed: 0  Unnamed: 0.1        date        level susp_age_group  \
# 0                0             0  12/23/2020       FELONY        UNKNOWN
# 1                1             1  12/21/2020       FELONY        UNKNOWN
# 2                2             2  11/22/2020       FELONY        UNKNOWN
# 3                3             3  11/22/2020       FELONY          25-44
# 4                4             4  11/21/2020       FELONY        UNKNOWN
# ...            ...           ...         ...          ...            ...
# 404846      404846        404887  01/04/2020  MISDEMEANOR        UNKNOWN
# 404847      404847        404888  01/02/2020       FELONY        UNKNOWN
# 404848      404848        404889  01/02/2020       FELONY          25-44
# 404849      404849        404890  01/05/2020  MISDEMEANOR          45-64
# 404850      404850        404891  01/01/2020       FELONY          25-44
#
#              susp_race susp_sex vic_age_group                  vic_race  \
# ...
